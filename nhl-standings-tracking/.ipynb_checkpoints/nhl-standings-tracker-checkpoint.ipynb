# %% [markdown]
# # Initialization - packages, create list of team abbreviations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.options.display.max_columns = None
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#repull from API for most up to date day of data
from sportsipy.nhl.teams import Teams

teams = Teams()

# %%
#creat list of team abbreviations
teams_abr = []
for team in teams:
    teams_abr.append(team.abbreviation)

# %%
from sportsipy.nhl.schedule import Schedule

# %% [markdown]
# # Pull each teams games/results by day over course of season to date, use for visualizations

# %%
#Update dataframe with each team's played games to date
#for later: add conference, divisions for filtering - can use teams_conference_division_reference dataframe below
#when plotting points over season: use 'game' column as x access to stay consistent across teams

time_series_df = pd.DataFrame()        #rename to time_series_df at some point

for abr in teams_abr:
    x_sch = Schedule(abr)           #get current team's schedule
    temp_df = x_sch.dataframe       
    temp_df['team'] = abr           #add team column
    time_series_df = time_series_df.append(temp_df)        #append to combined dataframe

time_series_df = time_series_df.loc[time_series_df['pdo'].notnull()].set_index('boxscore_index')   #use pdo to filter out games that have not been played yet

# %%
time_series_df
# Out:
#                       date   datetime  game goals_allowed goals_scored  \
# boxscore_index
# 202110120TBL    2021-10-12 2021-10-12     1             6            2
# 202110140DET    2021-10-14 2021-10-14     2             6            7
# 202110160WSH    2021-10-16 2021-10-16     3             1            2
# 202110190TBL    2021-10-19 2021-10-19     4             4            1
# 202110230TBL    2021-10-23 2021-10-23     5             4            3
# ...                    ...        ...   ...           ...          ...
# 202112060DAL    2021-12-06 2021-12-06    25             4            1
# 202112100ARI    2021-12-10 2021-12-10    26             3            1
# 202112110ARI    2021-12-11 2021-12-11    27             5            3
# 202112150ARI    2021-12-15 2021-12-15    28             3            2
# 202112170ANA    2021-12-17 2021-12-17    29             5            6
#
#                location opponent_abbr        opponent_name  overtime  \
# boxscore_index
# 202110120TBL       Home           PIT  Pittsburgh Penguins         0
# 202110140DET       Away           DET    Detroit Red Wings         1
# 202110160WSH       Away           WSH  Washington Capitals         1
# 202110190TBL       Home           FLA     Florida Panthers         0
# 202110230TBL       Home           COL   Colorado Avalanche        -1
# ...                 ...           ...                  ...       ...
# 202112060DAL       Away           DAL         Dallas Stars         0
# 202112100ARI       Home           FLA     Florida Panthers         0
# 202112110ARI       Home           PHI  Philadelphia Flyers         0
# 202112150ARI       Home           NYR     New York Rangers         0
# 202112170ANA       Away           ANA        Anaheim Ducks         1
#
#                penalties_in_minutes power_play_goals power_play_opportunities  \
# boxscore_index
# 202110120TBL                      2                0                        1
# 202110140DET                     20                3                        7
# 202110160WSH                      8                0                        1
# 202110190TBL                      6                0                        6
# 202110230TBL                     14                0                        3
# ...                             ...              ...                      ...
# 202112060DAL                      8                0                        1
# 202112100ARI                      8                1                        5
# 202112110ARI                      6                0                        2
# 202112150ARI                      8                0                        2
# 202112170ANA                     20                1                        4
#
#                result short_handed_goals shots_on_goal opp_shots_on_goal  \
# boxscore_index
# 202110120TBL     Loss                  0            28                35
# 202110140DET      Win                  0            48                26
# 202110160WSH      Win                  0            24                33
# 202110190TBL     Loss                  0            31                32
# 202110230TBL      OTL                  0            32                27
# ...               ...                ...           ...               ...
# 202112060DAL     Loss                  0            19                27
# 202112100ARI     Loss                  0            23                23
# 202112110ARI     Loss                  0            32                34
# 202112150ARI     Loss                  1            31                30
# 202112170ANA      Win                  0            27                37
#
#                opp_penalties_in_minutes opp_power_play_goals  \
# boxscore_index
# 202110120TBL                          2                    0
# 202110140DET                         26                    1
# 202110160WSH                          2                    0
# 202110190TBL                         12                    1
# 202110230TBL                          8                    1
# ...                                 ...                  ...
# 202112060DAL                          2                    1
# 202112100ARI                         10                    1
# 202112110ARI                          4                    1
# 202112150ARI                          6                    2
# 202112170ANA                         18                    2
#
#                opp_power_play_opportunities opp_short_handed_goals corsi_for  \
# boxscore_index
# 202110120TBL                              1                      0        52
# 202110140DET                              5                      0        48
# 202110160WSH                              4                      0        54
# 202110190TBL                              3                      0        36
# 202110230TBL                              6                      0        45
# ...                                     ...                    ...       ...
# 202112060DAL                              4                      0        32
# 202112100ARI                              4                      0        31
# 202112110ARI                              3                      0        53
# 202112150ARI                              3                      0        46
# 202112170ANA                              5                      0        29
#
#                corsi_against corsi_for_percentage fenwick_for fenwick_against  \
# boxscore_index
# 202110120TBL              57                 47.7          38              47
# 202110140DET              29                 62.3          41              23
# 202110160WSH              46                   54          38              33
# 202110190TBL              42                 46.2          30              31
# 202110230TBL              34                   57          39              26
# ...                      ...                  ...         ...             ...
# 202112060DAL              42                 43.2          22              27
# 202112100ARI              33                 48.4          22              27
# 202112110ARI              49                   52          40              36
# 202112150ARI              41                 52.9          38              34
# 202112170ANA              44                 39.7          27              34
#
#                fenwick_for_percentage faceoff_wins faceoff_losses  \
# boxscore_index
# 202110120TBL                     44.7           32             32
# 202110140DET                     64.1           24             19
# 202110160WSH                     53.5           24             25
# 202110190TBL                     49.2           31             17
# 202110230TBL                       60           28             22
# ...                               ...          ...            ...
# 202112060DAL                     44.9           24             24
# 202112100ARI                     44.9           21             20
# 202112110ARI                     52.6           21             20
# 202112150ARI                     52.8           13             32
# 202112170ANA                     44.3           22             22
#
#                faceoff_win_percentage offensive_zone_start_percentage    pdo  \
# boxscore_index
# 202110120TBL                       50                            46.3   90.3
# 202110140DET                     55.8                            57.9   85.8
# 202110160WSH                       49                            49.3  104.5
# 202110190TBL                     64.6                            59.4   92.5
# 202110230TBL                       56                            72.4    101
# ...                               ...                             ...    ...
# 202112060DAL                       50                            59.4     91
# 202112100ARI                     51.2                            44.4   89.5
# 202112110ARI                     51.2                            57.7   95.9
# 202112150ARI                     28.9                            36.4    100
# 202112170ANA                       50                            35.1  113.5
#
#                team
# boxscore_index
# 202110120TBL    TBL
# 202110140DET    TBL
# 202110160WSH    TBL
# 202110190TBL    TBL
# 202110230TBL    TBL
# ...             ...
# 202112060DAL    ARI
# 202112100ARI    ARI
# 202112110ARI    ARI
# 202112150ARI    ARI
# 202112170ANA    ARI
#
# [946 rows x 32 columns]

# %% [markdown]
# # Use teams dataframe to pull points, games_played, add games_remaining and points_per_game, and total_points_pace

# %%
teams_df = teams.dataframes

# %%
#update games remaining, pointers per game, and points pace based on latest day of data
teams_df['games_remaining'] = 82 - teams_df['games_played']
teams_df['points_per_game'] = teams_df['points'] / teams_df['games_played']
teams_df['total_points_pace'] = np.round(teams_df['points'] + (teams_df['games_remaining'] * teams_df['points_per_game']), 0)

# %%
#use this df & csv for sake of mapping conferences, divisions - manually updated csv to map teams 

##################### don't need to run this cell again ###################

teams_conference_div_reference_df = pd.read_csv('teams_conference_division_reference.csv').set_index('abbreviation').drop('Unnamed: 0', axis=1)

# %%
#create dictionaries for conference, division for reference
conferences = dict(zip(teams_conference_div_reference_df.index, teams_conference_div_reference_df.conference))
divisions = dict(zip(teams_conference_div_reference_df.index, teams_conference_div_reference_df.division))

# %%
#adds conferences and divisions to refreshed teams dataframe pulled from API
teams_df['conference'] = teams_df['abbreviation'].map(conferences)
teams_df['division'] = teams_df['abbreviation'].map(divisions)

# %%
#update file name to export and save as needed
teams_df.to_csv('teams_points_df_updated_12-27-21.csv')

# %%
#sort teams by conference, points pace
teams_df[['conference','division','name','points','points_percentage','games_played','total_points_pace']].sort_values(by=['conference','total_points_pace'], ascending=False)
# Out:
#     conference      division                   name  points  \
# MIN    Western       Central         Minnesota Wild      40
# COL    Western       Central     Colorado Avalanche      36
# NSH    Western       Central    Nashville Predators      39
# CGY    Western       Pacific         Calgary Flames      36
# STL    Western       Central        St. Louis Blues      39
# ANA    Western       Pacific          Anaheim Ducks      40
# VEG    Western       Pacific   Vegas Golden Knights      40
# EDM    Western       Pacific        Edmonton Oilers      36
# LAK    Western       Pacific      Los Angeles Kings      33
# WPG    Western       Central          Winnipeg Jets      33
# DAL    Western       Central           Dallas Stars      32
# SJS    Western       Pacific        San Jose Sharks      31
# VAN    Western       Pacific      Vancouver Canucks      30
# CHI    Western       Central     Chicago Blackhawks      26
# SEA    Western       Pacific         Seattle Kraken      23
# ARI    Western       Central        Arizona Coyotes      14
# CAR    Eastern  Metropolitan    Carolina Hurricanes      43
# TBL    Eastern      Atlantic    Tampa Bay Lightning      44
# TOR    Eastern      Atlantic    Toronto Maple Leafs      42
# NYR    Eastern  Metropolitan       New York Rangers      42
# WSH    Eastern  Metropolitan    Washington Capitals      43
# FLA    Eastern      Atlantic       Florida Panthers      40
# PIT    Eastern  Metropolitan    Pittsburgh Penguins      39
# BOS    Eastern      Atlantic          Boston Bruins      30
# DET    Eastern      Atlantic      Detroit Red Wings      33
# CBJ    Eastern  Metropolitan  Columbus Blue Jackets      29
# PHI    Eastern  Metropolitan    Philadelphia Flyers      29
# NYI    Eastern  Metropolitan     New York Islanders      22
# BUF    Eastern      Atlantic         Buffalo Sabres      25
# NJD    Eastern  Metropolitan      New Jersey Devils      25
# OTT    Eastern      Atlantic        Ottawa Senators      20
# MTL    Eastern      Atlantic     Montreal Canadiens      17
#
#      points_percentage  games_played  total_points_pace
# MIN              0.667            30              109.0
# COL              0.667            27              109.0
# NSH              0.650            30              107.0
# CGY              0.643            28              105.0
# STL              0.629            31              103.0
# ANA              0.625            32              102.0
# VEG              0.625            32              102.0
# EDM              0.621            29              102.0
# LAK              0.550            30               90.0
# WPG              0.550            30               90.0
# DAL              0.552            29               90.0
# SJS              0.517            30               85.0
# VAN              0.484            31               79.0
# CHI              0.433            30               71.0
# SEA              0.383            30               63.0
# ARI              0.241            29               40.0
# CAR              0.741            29              122.0
# TBL              0.733            30              120.0
# TOR              0.700            30              115.0
# NYR              0.700            30              115.0
# WSH              0.694            31              114.0
# FLA              0.690            29              113.0
# PIT              0.650            30              107.0
# BOS              0.577            26               95.0
# DET              0.532            31               87.0
# CBJ              0.518            28               85.0
# PHI              0.500            29               82.0
# NYI              0.423            26               69.0
# BUF              0.417            30               68.0
# NJD              0.417            30               68.0
# OTT              0.357            28               59.0
# MTL              0.274            31               45.0

# %% [markdown]
# # More time series dataframe work

# %%
#add in conference and division for filtering
#use index map bc time series df has team abbr as index, not separate column

time_series_df['conference'] = time_series_df['team'].map(conferences)
time_series_df['division'] = time_series_df['team'].map(divisions)

# %%
#add points_earned based on result column - this will be points earned from that single game

#create list of conditions
conditions = [(time_series_df['result'] == 'Win'), (time_series_df['result'] == 'OTL'), (time_series_df['result'] == 'Loss')]

#create list of values assigned to each division
values = [2, 1, 0]

#create new df column and use select function with above conditions and values as inputs
time_series_df['points_earned'] = np.select(conditions, values)

# %%
#add column for cumulative points total over course of season by team
time_series_df['rolling_points_total'] = time_series_df.groupby(['team'])['points_earned'].cumsum()

# %%
time_series_df.head()
# Out:
#                       date   datetime  game goals_allowed goals_scored  \
# boxscore_index
# 202110120TBL    2021-10-12 2021-10-12     1             6            2
# 202110140DET    2021-10-14 2021-10-14     2             6            7
# 202110160WSH    2021-10-16 2021-10-16     3             1            2
# 202110190TBL    2021-10-19 2021-10-19     4             4            1
# 202110230TBL    2021-10-23 2021-10-23     5             4            3
#
#                location opponent_abbr        opponent_name  overtime  \
# boxscore_index
# 202110120TBL       Home           PIT  Pittsburgh Penguins         0
# 202110140DET       Away           DET    Detroit Red Wings         1
# 202110160WSH       Away           WSH  Washington Capitals         1
# 202110190TBL       Home           FLA     Florida Panthers         0
# 202110230TBL       Home           COL   Colorado Avalanche        -1
#
#                penalties_in_minutes power_play_goals power_play_opportunities  \
# boxscore_index
# 202110120TBL                      2                0                        1
# 202110140DET                     20                3                        7
# 202110160WSH                      8                0                        1
# 202110190TBL                      6                0                        6
# 202110230TBL                     14                0                        3
#
#                result short_handed_goals shots_on_goal opp_shots_on_goal  \
# boxscore_index
# 202110120TBL     Loss                  0            28                35
# 202110140DET      Win                  0            48                26
# 202110160WSH      Win                  0            24                33
# 202110190TBL     Loss                  0            31                32
# 202110230TBL      OTL                  0            32                27
#
#                opp_penalties_in_minutes opp_power_play_goals  \
# boxscore_index
# 202110120TBL                          2                    0
# 202110140DET                         26                    1
# 202110160WSH                          2                    0
# 202110190TBL                         12                    1
# 202110230TBL                          8                    1
#
#                opp_power_play_opportunities opp_short_handed_goals corsi_for  \
# boxscore_index
# 202110120TBL                              1                      0        52
# 202110140DET                              5                      0        48
# 202110160WSH                              4                      0        54
# 202110190TBL                              3                      0        36
# 202110230TBL                              6                      0        45
#
#                corsi_against corsi_for_percentage fenwick_for fenwick_against  \
# boxscore_index
# 202110120TBL              57                 47.7          38              47
# 202110140DET              29                 62.3          41              23
# 202110160WSH              46                   54          38              33
# 202110190TBL              42                 46.2          30              31
# 202110230TBL              34                   57          39              26
#
#                fenwick_for_percentage faceoff_wins faceoff_losses  \
# boxscore_index
# 202110120TBL                     44.7           32             32
# 202110140DET                     64.1           24             19
# 202110160WSH                     53.5           24             25
# 202110190TBL                     49.2           31             17
# 202110230TBL                       60           28             22
#
#                faceoff_win_percentage offensive_zone_start_percentage    pdo  \
# boxscore_index
# 202110120TBL                       50                            46.3   90.3
# 202110140DET                     55.8                            57.9   85.8
# 202110160WSH                       49                            49.3  104.5
# 202110190TBL                     64.6                            59.4   92.5
# 202110230TBL                       56                            72.4    101
#
#                team conference  division  points_earned  rolling_points_total
# boxscore_index
# 202110120TBL    TBL    Eastern  Atlantic              0                     0
# 202110140DET    TBL    Eastern  Atlantic              2                     2
# 202110160WSH    TBL    Eastern  Atlantic              2                     4
# 202110190TBL    TBL    Eastern  Atlantic              0                     4
# 202110230TBL    TBL    Eastern  Atlantic              1                     5

# %%
time_series_df.to_csv('time_series_points_df.csv')

# %%
time_series_df.groupby(['team', 'conference'])['points_earned'].sum()
# Out:
# team  conference
# ANA   Western       40
# ARI   Western       14
# BOS   Eastern       30
# BUF   Eastern       25
# CAR   Eastern       43
# CBJ   Eastern       29
# CGY   Western       36
# CHI   Western       26
# COL   Western       36
# DAL   Western       32
# DET   Eastern       33
# EDM   Western       36
# FLA   Eastern       40
# LAK   Western       33
# MIN   Western       40
# MTL   Eastern       17
# NJD   Eastern       25
# NSH   Western       39
# NYI   Eastern       22
# NYR   Eastern       42
# OTT   Eastern       20
# PHI   Eastern       29
# PIT   Eastern       39
# SEA   Western       23
# SJS   Western       31
# STL   Western       39
# TBL   Eastern       44
# TOR   Eastern       42
# VAN   Western       30
# VEG   Western       40
# WPG   Western       33
# WSH   Eastern       43
# Name: points_earned, dtype: int64

# %% [markdown]
# # Time Series Visualizations

# %%
from adjustText import adjust_text

# %%
plt.figure(figsize=(15,15))
ax1 = sns.lineplot(x='game', y='rolling_points_total', hue = 'team', data = time_series_df)

ax1.yaxis.tick_right()

plt.title('All Teams - Points')

team_abr_update = time_series_df['team'].unique()

texts = []
count=0
for l in ax1.lines:
    y = l.get_ydata()
    x = l.get_xdata()
    if len(y)>0:
        texts.append(plt.text(x[-1],y[-1],(team_abr_update[count]+'-'+str(y[-1])))) #, color=l.get_color()
        #texts.append(ax1.annotate((teams_abr[count]+'-'+str(y[-1])), xy=(1,y[-1]), xycoords=('axes fraction', 'data'), color=l.get_color()))
    count += 1

adjust_text(texts, arrowprops=dict(arrowstyle="->", color='r', lw=0.5))

#, arrowprops=dict(arrowstyle="->", color='r', lw=0.5)
# Out:
# 21

# %%
conference_filter = 'Western'    #Eastern Western
plt.figure(figsize=(15,15))
ax1 = sns.lineplot(x='game', y='rolling_points_total', hue = 'team', data = time_series_df.loc[time_series_df['conference']==conference_filter])

ax1.yaxis.tick_right()

plt.title(conference_filter+' Conference Teams - Points')

team_abr_update = time_series_df.loc[time_series_df['conference']==conference_filter]['team'].unique()
texts = []
count=0
for l in ax1.lines:
    y = l.get_ydata()
    x = l.get_xdata()
    if len(y)>0:
        texts.append(plt.text(x[-1],y[-1],(team_abr_update[count]+'-'+str(y[-1])))) 
        #texts.append(ax1.annotate((teams_abr[count]+'-'+str(y[-1])), xy=(1,y[-1]), xycoords=('axes fraction', 'data'), color=l.get_color()))
    count += 1

adjust_text(texts, arrowprops=dict(arrowstyle="->", color='r', lw=0.5))

#, arrowprops=dict(arrowstyle="->", color='r', lw=0.5)
# Out:
# 4

# %%
conference_filter = 'Eastern'    #Eastern Western
plt.figure(figsize=(15,15))
ax1 = sns.lineplot(x='game', y='rolling_points_total', hue = 'team', data = time_series_df.loc[time_series_df['conference']==conference_filter])

ax1.yaxis.tick_right()

plt.title(conference_filter+' Conference Teams - Points')

team_abr_update = time_series_df.loc[time_series_df['conference']==conference_filter]['team'].unique()
texts = []
count=0
for l in ax1.lines:
    y = l.get_ydata()
    x = l.get_xdata()
    if len(y)>0:
        texts.append(plt.text(x[-1],y[-1],(team_abr_update[count]+'-'+str(y[-1])))) 
        #texts.append(ax1.annotate((teams_abr[count]+'-'+str(y[-1])), xy=(1,y[-1]), xycoords=('axes fraction', 'data'), color=l.get_color()))
    count += 1

adjust_text(texts, arrowprops=dict(arrowstyle="->", color='r', lw=0.5))

#, arrowprops=dict(arrowstyle="->", color='r', lw=0.5)
# Out:
# 4

# %%
time_series_df.loc[time_series_df['conference']=='Eastern'].groupby(['team', 'conference'])['points_earned'].sum()
# Out:
# team  conference
# BOS   Eastern       30
# BUF   Eastern       25
# CAR   Eastern       43
# CBJ   Eastern       29
# DET   Eastern       33
# FLA   Eastern       40
# MTL   Eastern       17
# NJD   Eastern       25
# NYI   Eastern       22
# NYR   Eastern       42
# OTT   Eastern       20
# PHI   Eastern       29
# PIT   Eastern       39
# TBL   Eastern       44
# TOR   Eastern       42
# WSH   Eastern       43
# Name: points_earned, dtype: int64

# %%
time_series_df.loc[time_series_df['conference']=='Western'].groupby(['team', 'conference'])['points_earned'].sum()
# Out:
# team  conference
# ANA   Western       40
# ARI   Western       14
# CGY   Western       36
# CHI   Western       26
# COL   Western       36
# DAL   Western       32
# EDM   Western       36
# LAK   Western       33
# MIN   Western       40
# NSH   Western       39
# SEA   Western       23
# SJS   Western       31
# STL   Western       39
# VAN   Western       30
# VEG   Western       40
# WPG   Western       33
# Name: points_earned, dtype: int64
